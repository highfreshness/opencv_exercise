# %%
import cv2

# %%
image = cv2.imread("scale.jpg")

# %%
print("width : {} pixels".format(image.shape[1]))
# Out:
# width : 1200 pixels

# %%
print("height : {} pixels".format(image.shape[0]))
# Out:
# height : 675 pixels

# %%
print("channels : {} ".format(image.shape[2]))
# Out:
# channels : 3

# %%
(b,g,r) = image[10,10]
print("Pixel at(10,10) - R{}, G{}, B{}".format(r, g, b))
# Out:
# Pixel at(10,10) - R11, G39, B149

# %%
image[10,10] = (0,0,255)
(b,g,r) = image[10,10]
print("Pixel at(10,10) - R{}, G{}, B{}".format(r, g, b))
# Out:
# Pixel at(10,10) - R255, G0, B0

# %%
corner = image[0:100, 0:200]
cv2.imshow("Corner", corner)
cv2.waitKey(0)
image[0:100, 0:200] = (0,255,0)

# %%
cv2.imshow("image", image)
cv2.waitKey(0)
# Out:
# -1

# %%
import numpy as np
green = (0,255,0)
canvas = np.zeros_like(image, )

# %%
cv2.line(canvas, (0,0), (300, 200), green)
cv2.imshow("Canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.rectangle(canvas, (10, 20), (60, 80), green)
cv2.imshow("Canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
red = (0,0,255)
cv2.rectangle(canvas, (50, 200), (200, 225), red, 5)
cv2.imshow("Canvas", canvas)
cv2.waitKey(0)
# Out:
# -1

# %%
blue = (255,0,0)
cv2.rectangle(canvas, (200, 50), (225, 125), blue, -1)
cv2.imshow("Canvas", canvas)
cv2.waitKey(0)
# Out:
# -1
